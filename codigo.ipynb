# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('centros-educativos-en-valencia.csv', sep=';')

# %%
df = df[['Geo Point','municipio_','dlibre','dgenerica_','regimen','direccion']].reset_index()

# %%
df.rename(columns={'Geo Point': 'Geo_Point'}, inplace=True)
df.rename(columns={'index': 'id'}, inplace=True)

# %%
#!pip install sqlalchemy
from sqlalchemy import create_engine
import pandas as pd
#!pip install mysqlclient

# %%
## CONEXION CHURRO SQL
host  = "35.241.241.239" # 
port = 3306 # puerto en sql
user="root"
password="mysql"
protocolo = "mysql+pymysql"
bbdd = "database" #opcional

# %%
churro = f"{protocolo}://{user}:{password}@{host}:{port}/{bbdd}"
churro
# Out:
# 'mysql+pymysql://root:mysql@35.241.241.239:3306/database'

# %%
engine = create_engine(churro)

# %%
df
# Out:
#       id                                Geo_Point municipio_  \
# 0      0  39.50261499907377, -0.41316999999999976  Burjassot
# 1      1    39.5302359990736, -0.3807020000000016   València
# 2      2  39.45169899907408, -0.37516600000000083   València
# 3      3   39.47401799907396, -0.3823219999999999   València
# 4      4   39.47543999907394, -0.3713410000000003   València
# ..   ...                                      ...        ...
# 529  529  39.48093999907391, -0.35487599999999997   València
# 530  530  39.45861799907405, -0.40538200000000024   València
# 531  531   39.48667399907386, -0.3945380000000012   València
# 532  532   39.43629299907419, -0.3964560000000006   València
# 533  533   39.47612999907393, -0.3816880000000005   València
#
#                                                 dlibre  \
# 0            CENTRE PRIVAT NATIVIDAD DE NUESTRA SEÑORA
# 1                           CEIP MANUEL GONZÁLEZ MARTÍ
# 2                          CENTRE PRIVAT MARTÍ SOROLLA
# ...

# %%
df.to_sql("mitabla", con=engine, if_exists="replace", index=False)
# Out:
# 534

# %%
query = """SELECT * FROM mitabla"""
pd.read_sql(query, con=engine)
# Out:
#       id                                Geo_Point municipio_  \
# 0      0  39.50261499907377, -0.41316999999999976  Burjassot
# 1      1    39.5302359990736, -0.3807020000000016   València
# 2      2  39.45169899907408, -0.37516600000000083   València
# 3      3   39.47401799907396, -0.3823219999999999   València
# 4      4   39.47543999907394, -0.3713410000000003   València
# ..   ...                                      ...        ...
# 529  529  39.48093999907391, -0.35487599999999997   València
# 530  530  39.45861799907405, -0.40538200000000024   València
# 531  531   39.48667399907386, -0.3945380000000012   València
# 532  532   39.43629299907419, -0.3964560000000006   València
# 533  533   39.47612999907393, -0.3816880000000005   València
#
#                                                 dlibre  \
# 0            CENTRE PRIVAT NATIVIDAD DE NUESTRA SEÑORA
# 1                           CEIP MANUEL GONZÁLEZ MARTÍ
# 2                          CENTRE PRIVAT MARTÍ SOROLLA
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 534 entries, 0 to 533
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          534 non-null    int64
#  1   Geo_Point   534 non-null    object
#  2   municipio_  534 non-null    object
#  3   dlibre      534 non-null    object
#  4   dgenerica_  534 non-null    object
#  5   regimen     534 non-null    object
#  6   direccion   534 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 29.3+ KB
